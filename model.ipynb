# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('E:\Internship\Movie Recomender System\Dataset.csv')
titles = pd.read_csv(
    'E:\Internship\Movie Recomender System\Movie_Id_Titles.csv')

# %%
data.isnull().sum()
# Out:
# user_id      0
# item_id      0
# rating       0
# timestamp    0
# dtype: int64

# %%
titles.isnull().sum()
# Out:
# item_id    0
# title      0
# dtype: int64

# %%
data = data.drop('timestamp', axis=1)

# %%
data
# Out:
#         user_id  item_id  rating
# 0             0       50       5
# 1             0      172       5
# 2             0      133       1
# 3           196      242       3
# 4           186      302       3
# ...         ...      ...     ...
# 99998       880      476       3
# 99999       716      204       5
# 100000      276     1090       1
# 100001       13      225       2
# 100002       12      203       3
#
# [100003 rows x 3 columns]

# %%
import seaborn as sns

data_frame = data[['user_id', 'rating']]

sns.heatmap(data_frame.corr(), annot=True)
sns.set(rc={'figure.figsize': (30, 30)})

# %%
data_frame_2 = data[['item_id', 'rating']]

sns.heatmap(data_frame_2.corr(), annot=True)
sns.set(rc={'figure.figsize': (10, 10)})

# %%
sns.pairplot(data_frame)

# %%
sns.pairplot(data_frame_2)
